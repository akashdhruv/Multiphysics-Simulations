# %%
# Import standard libraries
import os
import sys
import itertools

# %%
# Import libraries to manage arrays, plotting, and Flash-X datasets
import numpy
import matplotlib.pyplot as pyplot
import boxkit
from boxkit.library import Server as BoxServer

# %%
PROJECT_HOME="/home/akash/jobs/boiling-simulations/simulation/PoolBoiling/SingleBubble"

# %%
sedona = BoxServer(hostname="c361652l.cels.anl.gov", username="akash")
sedona.connect()
datasetLoc = {
    r"Buffer = 0.5" : PROJECT_HOME + os.sep + "jobnode.archive/buffer_0.5_long",
    r"Buffer = 1.0" : PROJECT_HOME + os.sep + "jobnode.archive/buffer_1.0_long",
}

fileNumList = [*range(1,401,5)]

datasetDict = {}
for dsetKey in datasetLoc.keys():
    datasetList = []
    for fileNum in fileNumList:
        dataset = boxkit.read_dataset(datasetLoc[dsetKey] 
                                      + os.sep 
                                      + "INS_Pool_Boiling_hdf5_plt_cnt_"
                                      + str(fileNum).zfill(4), source="flash", server=sedona)
        datasetList.append(boxkit.mergeblocks(dataset, ["temp", "dfun"]))
    datasetDict[dsetKey]=datasetList
sedona.close()
# Out:
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# [boxkit.resource.read]: Avoid multiprocessing for remote files
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [4], line 14
#      12 datasetList = []
#      13 for fileNum in fileNumList:
# ---> 14     dataset = boxkit.read_dataset(datasetLoc[dsetKey]
#      15                                   + os.sep
#      16                                   + "INS_Pool_Boiling_hdf5_plt_cnt_"
#      17                                   + str(fileNum).zfill(4), source="flash", server=sedona)
#      18     datasetList.append(boxkit.mergeblocks(dataset, ["temp", "dfun"]))
#      19 datasetDict[dsetKey]=datasetList
#
# File ~/Desktop/Akash/Workbench/BoxKit/boxkit/api/_read.py:44, in read_dataset(filename, source, storage, server, force_memmap, nthreads, backend)
#      41 if not storage:
#      42     storage = "numpy-memmap"
# ---> 44 data_attributes, block_attributes = resources.read.options[source](filename, server)
#      46 data = library.Data(storage=storage, **data_attributes)
#      47 blocklist = [library.Block(data, **attributes) for attributes in block_attributes]
#
# File ~/Desktop/Akash/Workbench/BoxKit/boxkit/resources/read/_flash.py:63, in read_flash(filename, server)
#      52 data_attributes = {
#      53     "nblocks": int(nblocks),
#      54     "nxb": int(nxb),
#    (...)
#      59     "variables": variables,
#      60 }
#      62 # Create block attributes
# ---> 63 block_attributes = [
#      64     {
#      65         "dx": inputfile["block size"][lblock][0] / nxb,
#      66         "dy": (
#      67             1.0
#      68             if inputfile["block size"][lblock][1] == 0.0
#      69             else inputfile["block size"][lblock][1] / nyb
#      70         ),
#      71         "dz": (
#      72             1.0
#      73             if inputfile["block size"][lblock][2] == 0.0
#      74             else inputfile["block size"][lblock][2] / nzb
#      75         ),
#      76         "xmin": inputfile["bounding box"][lblock][0][0],
#      77         "ymin": inputfile["bounding box"][lblock][1][0],
#      78         "zmin": inputfile["bounding box"][lblock][2][0],
#      79         "xmax": inputfile["bounding box"][lblock][0][1],
#      80         "ymax": inputfile["bounding box"][lblock][1][1],
#      81         "zmax": inputfile["bounding box"][lblock][2][1],
#      82         "tag": lblock,
#      83         "level": inputfile["refine level"][lblock],
#      84         "leaf": bool(inputfile["node type"][lblock] == 1),
#      85         "inputproc": inputfile["processor number"][lblock],
#      86     }
#      87     for lblock in range(nblocks)
#      88 ]
#      90 return data_attributes, block_attributes
#
# File ~/Desktop/Akash/Workbench/BoxKit/boxkit/resources/read/_flash.py:76, in <listcomp>(.0)
#      52 data_attributes = {
#      53     "nblocks": int(nblocks),
#      54     "nxb": int(nxb),
#    (...)
#      59     "variables": variables,
#      60 }
#      62 # Create block attributes
#      63 block_attributes = [
#      64     {
#      65         "dx": inputfile["block size"][lblock][0] / nxb,
#      66         "dy": (
#      67             1.0
#      68             if inputfile["block size"][lblock][1] == 0.0
#      69             else inputfile["block size"][lblock][1] / nyb
#      70         ),
#      71         "dz": (
#      72             1.0
#      73             if inputfile["block size"][lblock][2] == 0.0
#      74             else inputfile["block size"][lblock][2] / nzb
#      75         ),
# ---> 76         "xmin": inputfile["bounding box"][lblock][0][0],
#      77         "ymin": inputfile["bounding box"][lblock][1][0],
#      78         "zmin": inputfile["bounding box"][lblock][2][0],
#      79         "xmax": inputfile["bounding box"][lblock][0][1],
#      80         "ymax": inputfile["bounding box"][lblock][1][1],
#      81         "zmax": inputfile["bounding box"][lblock][2][1],
#      82         "tag": lblock,
#      83         "level": inputfile["refine level"][lblock],
#      84         "leaf": bool(inputfile["node type"][lblock] == 1),
#      85         "inputproc": inputfile["processor number"][lblock],
#      86     }
#      87     for lblock in range(nblocks)
#      88 ]
#      90 return data_attributes, block_attributes
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~/homebrew/lib/python3.11/site-packages/h5py/_hl/dataset.py:741, in Dataset.__getitem__(self, args, new_dtype)
#     739 if self._fast_read_ok and (new_dtype is None):
#     740     try:
# --> 741         return self._fast_reader.read(args)
#     742     except TypeError:
#     743         pass  # Fall back to Python read pathway below
#
# File h5py/_selector.pyx:370, in h5py._selector.Reader.read()
#
# File h5py/h5fd.pyx:163, in h5py.h5fd.H5FD_fileobj_read()
#
# File ~/Library/Python/3.11/lib/python/site-packages/paramiko-2.12.0-py3.11.egg/paramiko/file.py:168, in BufferedFile.readinto(self, buff)
#     160 def readinto(self, buff):
#     161     """
#     162     Read up to ``len(buff)`` bytes into ``bytearray`` *buff* and return the
#     163     number of bytes read.
#    (...)
#     166         The number of bytes read.
#     167     """
# --> 168     data = self.read(len(buff))
#     169     buff[: len(data)] = data
#     170     return len(data)
#
# File ~/Library/Python/3.11/lib/python/site-packages/paramiko-2.12.0-py3.11.egg/paramiko/file.py:219, in BufferedFile.read(self, size)
#     217     read_size = max(self._bufsize, read_size)
#     218 try:
# --> 219     new_data = self._read(read_size)
#     220 except EOFError:
#     221     new_data = None
#
# File ~/Library/Python/3.11/lib/python/site-packages/paramiko-2.12.0-py3.11.egg/paramiko/sftp_file.py:185, in SFTPFile._read(self, size)
#     183     if data is not None:
#     184         return data
# --> 185 t, msg = self.sftp._request(
#     186     CMD_READ, self.handle, long(self._realpos), int(size)
#     187 )
#     188 if t != CMD_DATA:
#     189     raise SFTPError("Expected data")
#
# File ~/Library/Python/3.11/lib/python/site-packages/paramiko-2.12.0-py3.11.egg/paramiko/sftp_client.py:822, in SFTPClient._request(self, t, *arg)
#     820 def _request(self, t, *arg):
#     821     num = self._async_request(type(None), t, *arg)
# --> 822     return self._read_response(num)
#
# File ~/Library/Python/3.11/lib/python/site-packages/paramiko-2.12.0-py3.11.egg/paramiko/sftp_client.py:852, in SFTPClient._read_response(self, waitfor)
#     850 while True:
#     851     try:
# --> 852         t, data = self._read_packet()
#     853     except EOFError as e:
#     854         raise SSHException("Server connection dropped: {}".format(e))
#
# File ~/Library/Python/3.11/lib/python/site-packages/paramiko-2.12.0-py3.11.egg/paramiko/sftp.py:201, in BaseSFTP._read_packet(self)
#     200 def _read_packet(self):
# --> 201     x = self._read_all(4)
#     202     # most sftp servers won't accept packets larger than about 32k, so
#     203     # anything with the high byte set (> 16MB) is just garbage.
#     204     if byte_ord(x[0]):
#
# File ~/Library/Python/3.11/lib/python/site-packages/paramiko-2.12.0-py3.11.egg/paramiko/sftp.py:185, in BaseSFTP._read_all(self, n)
#     183             break
#     184 else:
# --> 185     x = self.sock.recv(n)
#     187 if len(x) == 0:
#     188     raise EOFError()
#
# File ~/Library/Python/3.11/lib/python/site-packages/paramiko-2.12.0-py3.11.egg/paramiko/channel.py:699, in Channel.recv(self, nbytes)
#     686 """
#     687 Receive data from the channel.  The return value is a string
#     688 representing the data received.  The maximum amount of data to be
#    (...)
#     696     if no data is ready before the timeout set by `settimeout`.
#     697 """
#     698 try:
# --> 699     out = self.in_buffer.read(nbytes, self.timeout)
#     700 except PipeTimeout:
#     701     raise socket.timeout()
#
# File ~/Library/Python/3.11/lib/python/site-packages/paramiko-2.12.0-py3.11.egg/paramiko/buffered_pipe.py:160, in BufferedPipe.read(self, nbytes, timeout)
#     158 while (len(self._buffer) == 0) and not self._closed:
#     159     then = time.time()
# --> 160     self._cv.wait(timeout)
#     161     if timeout is not None:
#     162         timeout -= time.time() - then
#
# File ~/homebrew/Cellar/python@3.11/3.11.0/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
heatFluxDict = {}
for dsetKey in datasetDict.keys():
    heatFluxList = []
    for dset in datasetDict[dsetKey]:
        for block in dset.blocklist:
            #mean_hf = numpy.mean(((1 - block["temp"][0,0,:])/block.dy)*(block["dfun"][0,0,:]<0))
            #mean_phi = numpy.mean((block["dfun"][0,0,:]<0))
            #heatFluxList.append(mean_hf/mean_phi)
            mean_hf = numpy.mean((1 - block["temp"][0,0,:])/block.dy)
            heatFluxList.append(mean_hf)
    heatFluxDict[dsetKey] = heatFluxList

# %%
from scipy import signal
pyplot.figure(figsize=(12,8))
#pyplot.plot(fileNumList, heatFluxDict["Buffer = 0.5"])
pyplot.plot(fileNumList, signal.savgol_filter(heatFluxDict["Buffer = 0.5"],20,3))
pyplot.plot(fileNumList, signal.savgol_filter(heatFluxDict["Buffer = 1.0"],20,3))
pyplot.ylim([3.5,5])
